# %% [markdown]
# Reading the data

# %%
lines = open("kya.txt").read().splitlines()

# %%
# lines = open("sentences.txt").read().splitlines()

# %%
sentences = []

for line in lines:
    sentence = line.split(",")
    sentences.append([word for word in sentence[1].split()])

# %%
sentences[1]
# Out:
# ['ye', 'kya', 'tha', 'lavdi', 'ne', 'goli', 'mar', 'di', 'bc']

# %%
from gensim.models import Word2Vec
# from sklearn.decomposition import PCA
# from matplotlib import pyplot

# %%
# train model
model = Word2Vec(sentences, min_count=1)

# # fit a 2d PCA model to the vectors
# X = model[model.wv.vocab]
# pca = PCA(n_components=2)
# result = pca.fit_transform(X)
# # create a scatter plot of the projection
# pyplot.scatter(result[:, 0], result[:, 1])
# words = list(model.wv.vocab)
# for i, word in enumerate(words):
# 	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
# pyplot.show()

# %%
print(model)
# Out:
# Word2Vec(vocab=28636, size=100, alpha=0.025)

# %%
# summarize vocabulary
# words = list(model.wv.vocab)
# print(words)
# Out:
# ['mee', 'too', 'but', 'aaj', 'jaldi', 'chalke', 'dekhte', 'hai', 'call', 'kar', 'leti', 'hoon', 'light', 'abhi', 'i', 'will', 'try', 'attending', 'one', 'myself', 'agar', 'attendance', 'lag', 'gayi', 'toh', 'badhiya', 'main', 'kal', 'aayungi', 'shaadi', 'mei', 'directly', 'room', 'shayad', 'bhi', 'nahi', 'stay', 'karungi', 'cancel', 'ho', 'sakti', 'uski', 'booking', 'sorrrry', 'subah', 'tak', 'pata', 'nhi', 'tha', 'that', 'wudnt', 'be', 'able', 'to', 'come', 'today', 'was', 'really', 'trying', 'ki', 'aajayun', 'par', 'if', 'its', 'possible', 'and', 'any', 'other', 'guest', 'needs', 'a', 'mera', 'de', 'kisi', 'ko', 'hum', 'train', 'ticket', 'karwa', 'lenge', 'haha', 'of', 'course', 'am', 'sure', 'car', 'ek', 'doosre', 'ke', 'ghar', 'jaane', 'kaam', 'aayegi', 'btw', 'thinking', 'mai', 'pehle', 'chale', 'jaungi', 'sham', 'venue', 'pe', 'aa', 'can', 'happily', 'do', 'research', 'continue', 'the', 'foregin', 'interviews', 'aaram', 'se', 'now', 'jab', 'uthegi', 'kettle', 'baahar', 'rakh', 'dena', 'bhai', 'ka', 'function', 'un', 'din', 'alawa', 'kabhi', 'lena', 'na', 'dekh', 'itni', 'mehengi', 'jayegi', 'phir', 'tu', 'karegi', 'udhar', 'permanent', 'intezaam', 'karke', 'soch', 'hamare', 'college', 'k', 'saare', 'gujju', 'baithe', 'reh', 'jayenge', 'haan', 'fridge', 'khaali', 'pada', 'goa', 'mein', 'jaakar', 'beach', 'itna', 'shor', 'gokarna', 'yaad', 'rahe', 'timepass', 'hi', 'rha', 'hu', 'fir', 'kaafi', 'acchi', 'friend', 'bann', 'roz', 'khaane', 'bula', 'thi', 'like', 'degrees', 'walk', 'gaye', 'mujhe', 'last', 'sem', 'hostel', 'cooking', 'bhoot', 'sawaa', 'hua', 'kya', 'mast', 'shakes', 'aur', 'cold', 'coffee', 'banti', 'usse', 'maine', 'daddy', 'fb', 'khol', 'liya', 'ayur', 'profile', 'pic', 'laga', 'di', 'vaise', 'group', 'rakhna', 'is', 'good', 'idea', 'unke', 'side', 'photos', 'daal', 'please', 'have', 'recipe', 'what', 'made', 'day', 'jiski', 'photo', 'bheji', 'around', 'baje', 'inke', 'bahar', 'milte', 'hain', 'bata', 'hota', 'toe', 'kuch', 'plan', 'nahin', 'bana', 'yaar', 'keep', 'you', 'posted', 'weddings', 'jata', 'yeh', 'urgent', 'medical', 'leave', 'kaise', 'lete', 'tune', 'apne', 'gale', 'liye', 'li', 'tere', 'phone', 'jo', 'comic', 'con', 'woh', 'bhej', 'basic', 'details', 'bhar', 'bas', 'next', 'click', 'karna', 'essentially', 'saal', 'placement', 'intern', 'aisa', 'koi', 'doc', 'month', 'ekdum', 'chal', 'raha', 'tga', 'find', 'it', 'so', 'awesome', 'aadhe', 'log', 'wing', 'waalo', 'saath', 'haaan', 'sab', 'tumhare', 'padne', 'wale', 'he', 'has', 'not', 'been', 'working', 'on', 'my', 'previous', 'paper', 'bacha', 'laptop', 'then', 'see', 'make', 'sit', 'down', 'just', 'tell', 'me', 'phrases', 'jayega', 'subject', 'end', 'sabse', 'zyada', 'panga', 'uska', 'lets', 'hope', 'jaega', 'major', 'chunk', 'khatam', 'saari', 'awesomeness', 'ikatthi', 'le', 'seniors', 'block', 'thhey', 'thought', 'juniors', 'patake', 'phod', 'hian', 'fodenge', 'boys', 'diwali', 'mann', 'pura', 'uthaane', 'koshish', 'jaata', 'p', 'shit', 'bey', 'should', 'wingmates', 'nuske', 'tujhse', 'seekhe', 'baad', 'emailed', 'again', 'return', 'internship', 'baar', 'thoda', 'for', 'your', 'satisfaction', 'turkey', 'news', 'women', 'wala', 'think', 'specific', 'issue', 'hona', 'chaahiye', 'istanbul', 'in', 'general', 'safe', 'dont', 'go', 'places', 'are', 'supposed', 'which', 'true', 'with', 'most', 'cities', 'office', 'everybody', 'speaks', 'english', 'tension', 'word', 'mouth', 'refer', 'dunga', 'send', 'resume', 'along', 'startup', 'waise', 'kuchh', 'company', 'bare', 'cliche', 'dialogue', 'response', 'saala', 'check', 'karti', 'paise', 'aaye', 'ya', 'even', 'though', 'they', 'going', 'unko', 'dusra', 'set', 'ppl', 'list', 'aayi', 'realy', 'know', 'how', 'these', 'things', 'work', 'tera', 'dhyaan', 'aaya', 'whn', 'saw', 'this', 'tujhe', 'ditch', 'maar', 'diya', 'bulana', 'tab', 'hyderabad', 'aaega', 'apni', 'kismet', 'likha', 'milna', 'before', 'placements', 'jiske', 'paas', 'meri', 'lan', 'wire', 'kripya', 've', 'laute', 'dein', 'jinko', 'pichle', 'mess ...

# %%
# access vector for one word
print(model['haan'])
# Out:
# [ 0.5144828  -0.30342254 -0.36063123  0.13655905 -0.07738867  0.14838496
#  -0.46312946 -0.03357855  0.02045255 -0.12062778  0.11587643 -0.02246323
#  -0.01111881 -0.17968976 -0.0697536   0.00226861 -0.04554269  0.15272315
#   0.19253854  0.0517427  -0.01038929  0.04833865  0.17695585 -0.02583655
#  -0.03038509  0.07155069  0.29978716  0.00868868  0.01444054  0.31734276
#   0.3740728  -0.3863332  -0.43705937  0.0456909   0.21810475 -0.12332497
#   0.10310257  0.08905214  0.33746415 -0.22477794 -0.0464642   0.11272166
#  -0.1299742  -0.0713274   0.00083145 -0.17151967  0.01235635 -0.16940868
#   0.2000708   0.20059481  0.40902627  0.2438887   0.15828195 -0.03061802
#   0.10772026  0.03387485 -0.12398238 -0.30215287  0.03690316  0.06771293
#  -0.07823395  0.2273775  -0.03633626 -0.00331842  0.02939599  0.07115573
#  -0.32961223 -0.164672   -0.07637802 -0.07689922  0.08336181  0.01177608
#   0.20973808 -0.27489188  0.08235164  0.13314721 -0.0994627  -0.08073632
#  -0.12325206 -0.12665504 -0.19478998  0.0213113   0.3605382   0.06002485
#  -0.10868422  0.19526814  0.05581428 -0.35680592  0.05749903 -0.23132075
#   0.38602558 -0.06120412  0.38580516  0.0730792   0.06381782  0.34614956
#   0.06546548 -0.03168081 -0.16360226 -0.00579097]
# /home/abhishek/Workspace/env/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
# save model
model.save('model.bin')

# %%
# load model
new_model = Word2Vec.load('model.bin')
print(new_model)
# Out:
# Word2Vec(vocab=28636, size=100, alpha=0.025)

# %%
model.most_similar("aur")
# Out:
# /home/abhishek/Workspace/env/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('na', 0.9999475479125977),
#  ('hota', 0.9999170899391174),
#  ('par', 0.9999167323112488),
#  ('toh', 0.9999077916145325),
#  ('aaj', 0.9999022483825684),
#  ('aisa', 0.9999005198478699),
#  ('bol', 0.9998971223831177),
#  ('ek', 0.9998959898948669),
#  ('naam', 0.9998920559883118),
#  ('bat', 0.9998721480369568)]
